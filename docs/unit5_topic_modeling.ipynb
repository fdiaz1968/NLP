# %% [markdown]
# # Unidad 5 — Modelamiento de Tópicos🟠 Híbrido

# %% [markdown]
# ## Objetivos de aprendizaje- Estimar un modelo LDA con el paquete `topicmodels` y seleccionar k óptimo.- Comparar LDA con BERTopic en términos de coherencia y legibilidad de tópicos.- Aplicar un LLM para asignar etiquetas interpretables a los tópicos descubiertos.

# %% [markdown]
# ## Lecturas sugeridas- Blei, D. M., Ng, A. Y. & Jordan, M. I. (2003). Latent Dirichlet Allocation. JMLR, 3, 993-1022.- Grootendorst, M. (2022). BERTopic: Neural topic modeling with a class-based TF-IDF procedure. arXiv:2203.05794.

# %% [markdown]
# ## Desarrollo

# %%
# R: library(topicmodels)# TODO: convertir DFM a formato topicmodels, ajustar LDA, seleccionar k# Python:# from bertopic import BERTopic# TODO: ajustar BERTopic y comparar coherencia con LDA# TODO: usar un LLM para etiquetar tópicos
