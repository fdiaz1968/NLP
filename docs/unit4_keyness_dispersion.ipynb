# %% [markdown]
# # Unidad 4 — Keyness y Dispersión Textual🟠 Híbrido

# %% [markdown]
# ## Objetivos de aprendizaje- Calcular e interpretar keyness con chi-cuadrado y log-likelihood entre grupos de texto.- Visualizar la dispersión léxica a lo largo de un corpus con `textplot_xray()`.- Usar un LLM para generar narrativas interpretativas de los términos clave detectados.

# %% [markdown]
# ## Lecturas sugeridas- Gabrielatos, C. (2018). Keyness analysis: nature, metrics and techniques. En: *Corpus Approaches to Discourse*. Routledge.- Scott, M. (1997). PC analysis of key words. *Liverpool Papers in Language and Discourse*, 1.

# %% [markdown]
# ## Desarrollo

# %%
library(quanteda)library(quanteda.textstats)library(quanteda.textplots)# TODO: textstat_keyness(), textplot_keyness(), textplot_xray()# TODO (Python): usar un LLM para narrar los términos clave detectados
