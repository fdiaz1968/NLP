# %% [markdown]
# # Unidad 3 — Estadística Descriptiva🟢 R / Quanteda

# %% [markdown]
# ## Objetivos de aprendizaje- Calcular métricas de diversidad léxica: tokens, types, TTR y moving-average TTR.- Visualizar distribuciones de frecuencia e interpretar la ley de Zipf en corpus reales.- Producir wordclouds comparativos entre grupos de documentos.

# %% [markdown]
# ## Lecturas sugeridas- Manning, C. D. & Schütze, H. (1999). *Foundations of Statistical NLP*. MIT Press. Cap. 1-2.- Zipf, G. K. (1949). *Human Behavior and the Principle of Least Effort*. Addison-Wesley.

# %% [markdown]
# ## Desarrollo

# %%
library(quanteda)library(quanteda.textstats)library(quanteda.textplots)# TODO: textstat_lexdiv(), textstat_frequency(), textplot_wordcloud()
